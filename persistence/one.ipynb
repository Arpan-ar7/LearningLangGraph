# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openrouter import ChatOpenRouter
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver
load_dotenv()

# llm = HuggingFaceEndpoint(
#     repo_id="zai-org/GLM-5.3",
#     task="text-generation",
# )
# model = ChatHuggingFace(llm=llm)

llm=ChatOpenRouter(model='inclusionai/ling-3.0-flash-sante:free')

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure.",
#  'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure.", 'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-bf4a-612b-8002-49ae73d8c63f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-09-08T18:14:46.020945+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-9940-68f9-8001-70010f27a43a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure.", 'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-bf4a-612b-8002-49ae73d8c63f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-09-08T18:14:46.020945+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-9940-68f9-8001-70010f27a43a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure."}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-9940-68f9-8001-70010f27a43a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-09-08T18:14:42.032460+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c7a-6dd1-8000-1300e88abc81'}}, tasks=(PregelTask(id='1591ebb8-03f5-1dc2-f283-a95d843596e8', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c7a-6dd1-8000-1300e88abc81'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-09-08T18:14:35.660027+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c75-6fb4-bfff-4d1ae47dc97d'}}, tasks=(PregelTask(id='8fbdfe57-69c4-f03c-b1ae-7b7ffc76a7e4', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure."}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c75-6fb4-bfff-4d1ae47dc97d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-09-08T18:14:35.658027+00:00', parent_config=None, tasks=(PregelTask(id='e7e7505e-d1ad-cbe4-b192-45197ff3f08a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': "Here you go! 🍝\n\n**Why did the pasta break up with the sauce?**\n\nBecause it couldn't handle the *meatball*-ing pressure! 🍅\n\nAnd of course, the all-time classic:\n\n**What do you call fake spaghetti?**\n\nAn *im-pasta*! 😄",
#  'explanation': 'Here’s the breakdown of the wordplay:\n\n**Joke 1:**  \nThe humor comes from mixing cooking vocabulary with relationship/psychology language. “*Meatball*-ing pressure” treats “meatball” as a verb (like “mental” or “meeting” pressure), so the pasta is “breaking up” because it can’t deal with the emotional stress—except the stress is described using a food term. It’s the absurd substitution of kitchen talk for heart-to-heart talk that makes it funny.\n\n**Joke 2:**  \nThis is a straight-up homophone pun. “Im-pasta” sounds exactly like **imposter**—someone who is fake or pretending to be something they’re not. Since the spaghetti isn’t real, it’s an *impasta*.\n\nBoth jokes rely on the same trick: taking a pasta-related word and forcing it to sound like a completely different word to create a silly double meaning. 🍝'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure.", 'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-bf4a-612b-8002-49ae73d8c63f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-09-08T18:14:46.020945+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-9940-68f9-8001-70010f27a43a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure.", 'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-bf4a-612b-8002-49ae73d8c63f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-09-08T18:14:46.020945+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-9940-68f9-8001-70010f27a43a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure."}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-9940-68f9-8001-70010f27a43a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-09-08T18:14:42.032460+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c7a-6dd1-8000-1300e88abc81'}}, tasks=(PregelTask(id='1591ebb8-03f5-1dc2-f283-a95d843596e8', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke works as a pun on two different meanings of **"fold"** and **"pressure"**:\n\n**In poker:**\n- To "fold" means to give up your hand and forfeit the round.\n- "Under pressure" refers to high-stakes betting or tough decisions that force you to quit.\n\n**With pizza:**\n- A pizza literally "folds" (bends, droops, or collapses) when it’s under physical pressure—like heavy toppings, a soggy center, or trying to pick up a floppy slice.\n- It also faces pressure in the oven from the heat and weight of everything on top.\n\nSo the punchline merges the two ideas: just like a poker player who quits when the betting gets intense, a pizza "folds" (loses its structure) when things get too intense—except for the pizza, it’s a literal structural failure rather than a strategic retreat.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c7a-6dd1-8000-1300e88abc81'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-09-08T18:14:35.660027+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c75-6fb4-bfff-4d1ae47dc97d'}}, tasks=(PregelTask(id='8fbdfe57-69c4-f03c-b1ae-7b7ffc76a7e4', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why don't pizzas ever win at poker? Because they always fold under pressure."}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1abb12-5c75-6fb4-bfff-4d1ae47dc97d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-09-08T18:14:35.658027+00:00', parent_config=None, tasks=(PregelTask(id='e7e7505e-d1ad-cbe4-b192-45197ff3f08a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": '1f1abb12-5c7a-6dd1-8000-1300e88abc81'}})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": '1f1abb12-5c7a-6dd1-8000-1300e88abc81'}})
#
# NameError: name 'workflow' is not defined
