# %%
from langgraph.graph import StateGraph,START,END
from langchain_openrouter import ChatOpenRouter
from typing import Annotated,Literal,TypedDict
from langchain.messages import HumanMessage,SystemMessage

# %%
generator_llm=ChatOpenRouter(model='inclusionai/ling-3.0-flash-sante:free')
evaluator_llm=ChatOpenRouter(model="poolside/laguna-s-2.1:free")
optimizer_llm=ChatOpenRouter(model="inclusionai/ling-3.0-flash-fin:free")

# %%
# state
class TweetState(TypedDict):
    topic: str 
    tweet:str
    evaluat
